# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('Amazon_Products_Reviews_Dataset_UNCLEANED.xlsx')
df= data.copy()

# %% [markdown]
# - [] product_id remove B0 as most them have the same
# - [] product_name it shouldn't be having any any spaces
# - [] category has all capitals in few need to capitalize it
# - [] Discounted_price has Rs: in few and not and it has INR marks in few rest it is missing it has negative values
# - [] in actual_price it has same as Discounted_price and few they are in float like 699.00 it has negative values
# - [] rating_count it has '|'  '-1' '3'  '2' so few symbols int values and negative values it needs to be in float values
# - []  discount_percentage it has '-15%' '39' few are in negative and only integers without % symbol
# - [] change all the datatypes

# %% [markdown]
# kaggle gathered insights :
#
# - [x] product_id : Check duplicate values, remove extra spaces, ensure all Product IDs are in the same format.
# - [x] product_name : 30 missing values, remove extra spaces and convert to Proper Case.
# - [x] category : 30 missing values, remove extra spaces and standardize category names.
# - [x] Discounted_Price (INR) : Remove ₹, Rs., commas and spaces, convert data type to Float, all values should be > 0.
# - [x] actual_price : Remove ₹ and commas, convert data type to Float, all values should be > 0 and greater than or equal to Discounted Price.
# - [x] discount_percentage : Remove % symbol, convert data type to Float, all values should be > 0 and < 100.
# - [x] rating : Missing values, convert data type to Float, rating should be between 1 and 5.
# - [x] Rating Count : Remove commas, convert data type to Int, all values should be ≥ 0.
# - [x] about_product : 30 missing values, remove extra spaces and unwanted special characters.
# - [x] user_id : 30 missing values, ensure proper formatting and remove extra spaces.
# - [x] user_name : 30 missing values, convert into Proper Case and remove extra spaces.
# - [x] review_id : Check duplicate values and ensure all Review IDs are unique.
# - [x] review_title : 30 missing values, remove extra spaces and unwanted symbols.
# - [x] review_content : 30 missing values, clean unwanted spaces, special characters and blank text.
# - [x]IMG_LINK : 30 missing values, ensure all links are valid and start with https://.
# - [x] product_link : 30 missing values, ensure all links are valid and remove broken URLs.
# - [x] Duplicate Records : Remove duplicate rows from the dataset.
# - [x] Missing Values : Fill numeric columns with Median and categorical columns with Mode or "Unknown".
# - [x] Data Type : Convert all price, rating, discount and rating count columns into appropriate numeric data types.

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'Discounted_Price (INR)',
#        'actual_price', 'discount_percentage', 'rating', 'Rating Count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'IMG_LINK ', 'product_link'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1495 entries, 0 to 1494
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1479 non-null   object
#  1   product_name            1476 non-null   object
#  2   category                1473 non-null   object
#  3   Discounted_Price (INR)  1473 non-null   object
#  4   actual_price            1473 non-null   object
#  5   discount_percentage     1473 non-null   object
#  6   rating                  1470 non-null   object
#  7   Rating Count            1468 non-null   object
#  8   about_product           1473 non-null   object
#  9   user_id                 1487 non-null   object
#  10  user_name               1486 non-null   object
#  11  review_id               1487 non-null   object
#  12  review_title            1481 non-null   object
#  13  review_content          1483 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# product_id                16
# product_name              19
# category                  22
# Discounted_Price (INR)    22
# actual_price              22
# discount_percentage       22
# rating                    25
# Rating Count              27
# about_product             22
# user_id                    8
# user_name                  9
# review_id                  8
# review_title              14
# review_content            12
# IMG_LINK                  19
# product_link              19
# dtype: int64

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.describe(include='all')
# Out:
#         product_id                                       product_name  \
# count         1473                                               1470
# unique        1350                                               1346
# top     B08DDRGWTJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             4                                                  5
#
#                                                  category  \
# count                                                1467
# unique                                                260
# top     Computers&Accessories|Accessories&Peripherals|...
# freq                                                  222
#
#        Discounted_Price (INR) actual_price discount_percentage rating  \
# count                    1467         1467                1467   1464
# unique                    610          520                 141     32
# top                      ₹199         ₹999                 60%    4.1
# ...

# %%
columns = df.columns

for i in columns:
    print(i)
    print(df[i].unique())
# Out:
# product_id
# ['B08SMJT55F' 'B07F6GXNPB' 'B08TTRVWKY' ... 'B091JF2TFD' 'B0B3JSWG81'
#  'B00PVT30YI']
# product_name
# ['boAt Stone 250 Portable Wireless Speaker with 5W RMS Immersive Audio, RGB LEDs, Up to 8HRS Playtime, IPX7 Water Resistance, Multi-Compatibility Modes(Black)'
#  'EUREKA FORBES EUROCLEAN PAPER VACUUM CLEANER DUST BAGS FOR EXCEL, ACE, 300, JET MODELS - SET OF 10'
#  'MILTON Smart Egg Boiler 360-Watts (Transparent and Silver Grey), Boil Up to 7 Eggs'
#  ...
#  'Boult Audio BassBuds Oak in-Ear Wired Earphones with 10mm Extra Bass Driver and HD Sound with mic(Brown)'
#  'NGI Store 2 Pieces Pet Hair Removers for Your Laundry Catcher Lint Remover for Washing Machine Lint Remover Reusable Portable Silica Gel Clothes Washer Dryer Floating Ball'
#  'Kitchen Mart Stainless Steel South Indian Filter Coffee Drip Maker, Madras Kappi, Drip Decotion Maker160ml (2 Cup)']
# category
# ['Electronics|HomeAudio|Speakers|BluetoothSpeakers'
# ...

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B08SMJT55F  boAt Stone 250 Portable Wireless Speaker with ...
# 1     B07F6GXNPB  EUREKA FORBES EUROCLEAN PAPER VACUUM CLEANER D...
# 2     B08TTRVWKY  MILTON Smart Egg Boiler 360-Watts (Transparent...
# 3     B01MQ2A86A  Logitech M331 Silent Plus Wireless Mouse, 2.4G...
# 4     B08GM5S4CQ  Havells Instanio 10 Litre Storage Water Heater...
# ...          ...                                                ...
# 1490  B0756K5DYZ  Prestige Iris 750 Watt Mixer Grinder with 3 St...
# 1491  B01LY9W8AF  Cello Eliza Plastic Laundry Bag/Basket, 50 lit...
# 1492  B091JF2TFD  Boult Audio BassBuds Oak in-Ear Wired Earphone...
# 1493  B0B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1494  B00PVT30YI  Kitchen Mart Stainless Steel South Indian Filt...
#
#                                                category  \
# 0      Electronics|HomeAudio|Speakers|BluetoothSpeakers
# ...

# %% [markdown]
# 1. Product_id

# %%
df['product_id'].str.contains('B0').sum()
# Out:
# 1454

# %%
df['product_id'].shape
df['product_id'].isna().sum()
# Out:
# np.int64(9)

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B08SMJT55F  boAt Stone 250 Portable Wireless Speaker with ...
# 1     B07F6GXNPB  EUREKA FORBES EUROCLEAN PAPER VACUUM CLEANER D...
# 2     B08TTRVWKY  MILTON Smart Egg Boiler 360-Watts (Transparent...
# 3     B01MQ2A86A  Logitech M331 Silent Plus Wireless Mouse, 2.4G...
# 4     B08GM5S4CQ  Havells Instanio 10 Litre Storage Water Heater...
# ...          ...                                                ...
# 1490  B0756K5DYZ  Prestige Iris 750 Watt Mixer Grinder with 3 St...
# 1491  B01LY9W8AF  Cello Eliza Plastic Laundry Bag/Basket, 50 lit...
# 1492  B091JF2TFD  Boult Audio BassBuds Oak in-Ear Wired Earphone...
# 1493  B0B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1494  B00PVT30YI  Kitchen Mart Stainless Steel South Indian Filt...
#
#                                                category  \
# 0      Electronics|HomeAudio|Speakers|BluetoothSpeakers
# ...

# %%
df['product_id'] = df['product_id'].str.replace('B0' , '')
df['product_id'] = df['product_id'].str.replace('b0' , '')
df
# df.loc[~df['product_id'].str.startswith('B0' , na= False) ,'product_id']
# Out:
#      product_id                                       product_name  \
# 0      8SMJT55F  boAt Stone 250 Portable Wireless Speaker with ...
# 1      7F6GXNPB  EUREKA FORBES EUROCLEAN PAPER VACUUM CLEANER D...
# 2      8TTRVWKY  MILTON Smart Egg Boiler 360-Watts (Transparent...
# 3      1MQ2A86A  Logitech M331 Silent Plus Wireless Mouse, 2.4G...
# 4      8GM5S4CQ  Havells Instanio 10 Litre Storage Water Heater...
# ...         ...                                                ...
# 1490   756K5DYZ  Prestige Iris 750 Watt Mixer Grinder with 3 St...
# 1491   1LY9W8AF  Cello Eliza Plastic Laundry Bag/Basket, 50 lit...
# 1492   91JF2TFD  Boult Audio BassBuds Oak in-Ear Wired Earphone...
# 1493   B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1494   0PVT30YI  Kitchen Mart Stainless Steel South Indian Filt...
#
#                                                category  \
# 0      Electronics|HomeAudio|Speakers|BluetoothSpeakers
# ...

# %%
df.loc[~df['product_id'].str.startswith('B0' , na= False) ,'product_id']
# Out:
# 0       8SMJT55F
# 1       7F6GXNPB
# 2       8TTRVWKY
# 3       1MQ2A86A
# 4       8GM5S4CQ
#           ...
# 1490    756K5DYZ
# 1491    1LY9W8AF
# 1492    91JF2TFD
# 1493    B3JSWG81
# 1494    0PVT30YI
# Name: product_id, Length: 1482, dtype: object

# %%
df['product_id'].isna().sum()
df['product_id'] = df['product_id'].fillna('Unknown')

# %%
df['product_id'].isna().sum()
# Out:
# np.int64(0)

# %%
df['product_id'].duplicated().sum()
# Out:
# np.int64(131)

# %%
df['product_id'] = df['product_id'].str.strip()

# %% [markdown]
# 2. Product_name

# %%
df
# Out:
#      product_id                                       product_name  \
# 0      8SMJT55F  boAt Stone 250 Portable Wireless Speaker with ...
# 1      7F6GXNPB  EUREKA FORBES EUROCLEAN PAPER VACUUM CLEANER D...
# 2      8TTRVWKY  MILTON Smart Egg Boiler 360-Watts (Transparent...
# 3      1MQ2A86A  Logitech M331 Silent Plus Wireless Mouse, 2.4G...
# 4      8GM5S4CQ  Havells Instanio 10 Litre Storage Water Heater...
# ...         ...                                                ...
# 1490   756K5DYZ  Prestige Iris 750 Watt Mixer Grinder with 3 St...
# 1491   1LY9W8AF  Cello Eliza Plastic Laundry Bag/Basket, 50 lit...
# 1492   91JF2TFD  Boult Audio BassBuds Oak in-Ear Wired Earphone...
# 1493   B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1494   0PVT30YI  Kitchen Mart Stainless Steel South Indian Filt...
#
#                                                category  \
# 0      Electronics|HomeAudio|Speakers|BluetoothSpeakers
# ...

# %%
df['product_name'].isna().sum()
# Out:
# np.int64(12)

# %%
df['product_name'] = df['product_name'].str.capitalize()

# %%
df[df['product_name'] == df['product_name'].str.upper()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, Discounted_Price (INR), actual_price, discount_percentage, rating, Rating Count, about_product, user_id, user_name, review_id, review_title, review_content, IMG_LINK , product_link]
# Index: []

# %%
df['product_name'] = df['product_name'].str.strip()

# %% [markdown]
# 3. Categories
# category : 30 missing values, remove extra spaces and standardize category names.

# %%
df['category'].isna().sum()
df[df['category'] == df['category'].str.upper()]
df['category'] = df['category'].str.capitalize()

# %%
df[df['category'] == df['category'].str.upper()].sum()
# Out:
# product_id                0
# product_name              0
# category                  0
# Discounted_Price (INR)    0
# actual_price              0
# discount_percentage       0
# rating                    0
# Rating Count              0
# about_product             0
# user_id                   0
# user_name                 0
# review_id                 0
# review_title              0
# review_content            0
# IMG_LINK                  0
# product_link              0
# dtype: object

# %%
df['category'].duplicated().sum()
# Out:
# np.int64(1244)

# %%
df['category'] = df['category'].str.strip()

# %% [markdown]
# 4 . Discounted price
# Discounted_Price (INR) : Remove ₹, Rs., commas and spaces, convert data type to Float, all values should be > 0.

# %%
df
# Out:
#      product_id                                       product_name  \
# 0      8SMJT55F  Boat stone 250 portable wireless speaker with ...
# 1      7F6GXNPB  Eureka forbes euroclean paper vacuum cleaner d...
# 2      8TTRVWKY  Milton smart egg boiler 360-watts (transparent...
# 3      1MQ2A86A  Logitech m331 silent plus wireless mouse, 2.4g...
# 4      8GM5S4CQ  Havells instanio 10 litre storage water heater...
# ...         ...                                                ...
# 1490   756K5DYZ  Prestige iris 750 watt mixer grinder with 3 st...
# 1491   1LY9W8AF  Cello eliza plastic laundry bag/basket, 50 lit...
# 1492   91JF2TFD  Boult audio bassbuds oak in-ear wired earphone...
# 1493   B3JSWG81  Ngi store 2 pieces pet hair removers for your ...
# 1494   0PVT30YI  Kitchen mart stainless steel south indian filt...
#
#                                                category  \
# 0      Electronics|homeaudio|speakers|bluetoothspeakers
# ...

# %%
df['Discounted_Price (INR)'].isnull().sum()
df.loc[~df['Discounted_Price (INR)'].str.contains('₹|Rs|,|\s', na=False), ['Discounted_Price (INR)']]
# Out:
#      Discounted_Price (INR)
# 3                       NaN
# 40                      289
# 54                      299
# 84                      449
# 110                     249
# ...                     ...
# 1395                    599
# 1397                   1399
# 1412                   5799
# 1436                    115
# 1463                    599
#
# [62 rows x 1 columns]

# %%
# df['Discounted_Price (INR)'] = df['Discounted_Price (INR)'].str.replace('₹' , '')
# df['Discounted_Price (INR)'] = df['Discounted_Price (INR)'].str.replace('Rs. ' , '')
# df['Discounted_Price (INR)'] = df['Discounted_Price (INR)'].str.replace(',' , '')
df['Discounted_Price (INR)'] = df['Discounted_Price (INR)'].str.replace('₹|Rs\. |,', '' , regex=True)
df['Discounted_Price (INR)']
# Out:
# 0         1199
# 1          253
# 2         1099
# 3          NaN
# 4         6990
#          ...
# 1490      3249
# 1491    998.06
# 1492       499
# 1493       199
# 1494       292
# Name: Discounted_Price (INR), Length: 1482, dtype: object

# %%
df['Discounted_Price (INR)'] = pd.to_numeric(df['Discounted_Price (INR)'].str.strip().str.replace('\s+', '', regex=True),errors='coerce')
df['Discounted_Price (INR)'] = df['Discounted_Price (INR)'].astype('float')

# %%
df['Discounted_Price (INR)'].dtype
# Out:
# dtype('float64')

# %%
df[df['Discounted_Price (INR)'] < 0]
# Out:
#      product_id                                       product_name  \
# 365    9L8DSSFH  7seven® compatible for samsung smart 4k ultra ...
# 539    1I1LDZGA  Pigeon kessel multipurpose kettle (12173) 1.2 ...
# 947    8CTNJ985  Wayona usb type c 65w fast charging 2m/6ft lon...
# 1088   8CYNJ5KY                Hp 682 black original ink cartridge
# 1133   9474JWN6  Healthsense rechargeable lint remover for clot...
# 1213   9DSQXCM8  House of quirk reusable sticky picker cleaner ...
# 1313   123P3PWE  Rico irpro 1500 watt japanese technology elect...
# 1325   B19VJXQZ  Ecovacs deebot n8 2-in-1 robotic vacuum cleane...
#
#                                                category  \
# 365   Electronics|hometheater,tv&video|accessories|r...
# 539   Home&kitchen|kitchen&homeappliances|smallkitch...
# 947   Computers&accessories|accessories&peripherals|...
# 1088  Computers&accessories|printers,inks&accessorie...
# 1133  Home&kitchen|kitchen&homeappliances|vacuum,cle...
# ...

# %%
df.loc[df['Discounted_Price (INR)'] <= 0] = np.nan
df['Discounted_Price (INR)'] = df['Discounted_Price (INR)'].fillna(df['Discounted_Price (INR)'].median())

# %%
df['Discounted_Price (INR)'].head()
df['Discounted_Price (INR)'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 5 . Actual_price :
# actual_price : Remove ₹ and commas, convert data type to Float, all values should be > 0 and greater than or equal to Discounted Price.

# %%
df['actual_price']
# Out:
# 0        ₹3,990
# 1          ₹500
# 2        ₹1,899
# 3        ₹1,645
# 4       ₹14,290
#          ...
# 1490     ₹6,295
# 1491     ₹1,282
# 1492     ₹1,299
# 1493       ₹999
# 1494       ₹499
# Name: actual_price, Length: 1482, dtype: object

# %%
df['actual_price'] = df['actual_price'].str.replace('₹|,|Rs.','' , regex = True,)
df.loc[~df['actual_price'].str.contains('₹|,|Rs. ',regex=True, na=False),['actual_price']]
# Out:
#      actual_price
# 0            3990
# 1             500
# 2            1899
# 3            1645
# 4           14290
# ...           ...
# 1490         6295
# 1491         1282
# 1492         1299
# 1493          999
# 1494          499
#
# [1482 rows x 1 columns]

# %%
df['actual_price']
# Out:
# 0        3990
# 1         500
# 2        1899
# 3        1645
# 4       14290
#         ...
# 1490     6295
# 1491     1282
# 1492     1299
# 1493      999
# 1494      499
# Name: actual_price, Length: 1482, dtype: object

# %%
df['actual_price'] = df['actual_price'].astype('float')

# %%
df.loc[~(df['actual_price'].abs() >= df['Discounted_Price (INR)'])]
# Out:
#      product_id                                       product_name  \
# 13          NaN                                                NaN
# 183         NaN                                                NaN
# 289    94JB13XL  Noise colorfit ultra smart watch with 1.75" hd...
# 329     Unknown                                                NaN
# 331    83342NKJ  Mi braided usb type-c cable for charging adapt...
# 365         NaN                                                NaN
# 396    0LOD70SC  Pilot v7 liquid ink roller ball pen (2 blue + ...
# 401    8VS3YLRK  Portronics adapto 20 type c 20w fast pd/type c...
# 419    994GFWBH  Lapster 1.5 mtr usb 2.0 type a male to usb a m...
# 539         NaN                                                NaN
# 543    B5CGTBKV  Boat wave call smart watch, smart talk with ad...
# 583    7YL54NVJ  Brand conquer 6 in 1 with otg, sd card reader,...
# 704    9NL4DCXK  Flix (beetel) bolt 2.4 12w dual usb smart char...
# ...

# %%
df.loc[df['actual_price'] <= 0] = np.nan

# %%
df['actual_price'] = df['actual_price'].fillna(df['actual_price'].median())

# %%
df['actual_price'].dtype
# Out:
# dtype('float64')

# %%
df.loc[~(df['actual_price'].abs() >= df['Discounted_Price (INR)'])]
# Out:
#      product_id                                       product_name  \
# 100         NaN                                                NaN
# 289    94JB13XL  Noise colorfit ultra smart watch with 1.75" hd...
# 331         NaN                                                NaN
# 396    0LOD70SC  Pilot v7 liquid ink roller ball pen (2 blue + ...
# 543    B5CGTBKV  Boat wave call smart watch, smart talk with ad...
# 583         NaN                                                NaN
# 704    9NL4DCXK  Flix (beetel) bolt 2.4 12w dual usb smart char...
# 753         NaN                                                NaN
# 787         NaN                                                NaN
# 871    1M69WCZ6  Allin exporters j66 ultrasonic humidifier cool...
# 893         NaN                                                NaN
# 957    0ZRBWPA0       Eveready red 1012 aaa batteries - pack of 10
# 1046        NaN                                                NaN
# ...

# %%
df['Discounted_Price (INR)'].isna().sum()
# Out:
# np.int64(13)

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.loc[~(df['actual_price'].abs() >= df['Discounted_Price (INR)'])]
# Out:
#      product_id                                       product_name  \
# 100         NaN                                                NaN
# 289    94JB13XL  Noise colorfit ultra smart watch with 1.75" hd...
# 396    0LOD70SC  Pilot v7 liquid ink roller ball pen (2 blue + ...
# 543    B5CGTBKV  Boat wave call smart watch, smart talk with ad...
# 704    9NL4DCXK  Flix (beetel) bolt 2.4 12w dual usb smart char...
# 871    1M69WCZ6  Allin exporters j66 ultrasonic humidifier cool...
# 957    0ZRBWPA0       Eveready red 1012 aaa batteries - pack of 10
# 1125   B2CWRDB1  Shakti technology s5 high pressure car washer ...
# 1239   97XJQZ8H  Cookwell bullet mixer grinder (5 jars, 3 blade...
#
#                                                category  \
# 100                                                 NaN
# 289         Electronics|wearabletechnology|smartwatches
# 396   Officeproducts|officepaperproducts|paper|stati...
# 543                                                 NaN
# ...

# %% [markdown]
# discount_percentage : Remove % symbol, convert data type to Float, all values should be > 0 and < 100.

# %%
df[~df['discount_percentage'].str.contains('%' , regex=True , na=False)]
df['discount_percentage'] = df['discount_percentage'].str.replace('%','',)
df['discount_percentage'] = df['discount_percentage'].astype('float')
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1704742589.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['discount_percentage'] = df['discount_percentage'].str.replace('%','',)
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1704742589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['discount_percentage'] = df['discount_percentage'].astype('float')

# %%
df['discount_percentage'].dtype
# Out:
# dtype('float64')

# %%
df.loc[df['discount_percentage'] <= 0]
# Out:
#      product_id                                       product_name  \
# 33     0URH5E34  Inventis 5v 1.2w portable flexible usb led lig...
# 57     7VV37FT4  Classmate octane neon- 25 blue gel pens | smoo...
# 62     71vnhmx2  Philips daily collection hd2582/00 830-watt 2-...
# 71     B4PPD89B  Kitchenwell 18pc plastic food snack bag pouch ...
# 94     B3CPQ5PF  Oneplus nord 2t 5g (jade fog, 8gb ram, 128gb s...
# 98     0E9G8KOY  Hul pureit germkill kit for classic 23 l water...
# 101    8TDJNM3G  E-cosmos 5v 1.2w portable flexible usb led lig...
# 229    0K32PEW4  Casio mj-120d 150 steps check and correct desk...
# 237    0DJ5N9VK  Faber-castell connector pen set - pack of 25 (...
# 258    0YQLG7GK     Philips hl1655/00 hand blender, white jar 250w
# 274    8HQL67D6  Ofixo multi-purpose laptop table/study table/b...
# 281    95X38CJS  Brustro copytinta coloured craft paper a4 size...
# 341    0LY17RHI      Camlin elegante fountain pen - black/blue/red
# ...

# %%
df.loc[df['discount_percentage'] <= 0] = 0

# %%
df.loc[df['discount_percentage'] <= 0]

# it is better to go Zero rather compute median on this discount_percentage as it might create outlier
# we only see one negative values
# Out:
#      product_id product_name category  Discounted_Price (INR)  actual_price  \
# 33            0            0        0                     0.0           0.0
# 57            0            0        0                     0.0           0.0
# 62            0            0        0                     0.0           0.0
# 71            0            0        0                     0.0           0.0
# 94            0            0        0                     0.0           0.0
# 98            0            0        0                     0.0           0.0
# 101           0            0        0                     0.0           0.0
# 229           0            0        0                     0.0           0.0
# 237           0            0        0                     0.0           0.0
# 258           0            0        0                     0.0           0.0
# 274           0            0        0                     0.0           0.0
# ...

# %%
df.loc[df['discount_percentage'] >= 100]
# Out:
#      product_id                                       product_name  \
# 476    7WDK3ZS6  Iqoo z6 lite 5g by vivo (mystic night, 6gb ram...
# 647    96MSW6CT  Sounce fast phone charging cable & data sync u...
# 766    97r25dp7  Noise colorfit pulse smartwatch with 3.56 cm (...
# 779    819ZZK5K  Sandisk ultra dual drive go usb type c pendriv...
# 807    BM4KTNL1  Figment handheld milk frother rechargeable, 3-...
# 996    85DTN6R2  Portronics konnect cl 20w por-1067 type-c to 8...
# 1227   7J2NGB69  Lenovo 400 wireless mouse, 1200dpi optical sen...
#
#                                                category  \
# 476   Electronics|mobiles&accessories|smartphones&ba...
# 647   Computers&accessories|accessories&peripherals|...
# 766         Electronics|wearabletechnology|smartwatches
# 779   Computers&accessories|externaldevices&datastor...
# 807   Home&kitchen|kitchen&homeappliances|smallkitch...
# 996   Computers&accessories|accessories&peripherals|...
# ...

# %%
df[df['discount_percentage'] >= 100] = np.nan
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/488467112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['discount_percentage'] >= 100] = np.nan

# %%
df['discount_percentage'] = df['discount_percentage'].fillna(df['discount_percentage'].median())
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/3809434304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['discount_percentage'] = df['discount_percentage'].fillna(df['discount_percentage'].median())

# %%
df[df['discount_percentage'] > 0]
# Out:
#      product_id                                       product_name  \
# 0      8SMJT55F  Boat stone 250 portable wireless speaker with ...
# 1      7F6GXNPB  Eureka forbes euroclean paper vacuum cleaner d...
# 2      8TTRVWKY  Milton smart egg boiler 360-watts (transparent...
# 3      1MQ2A86A  Logitech m331 silent plus wireless mouse, 2.4g...
# 4      8GM5S4CQ  Havells instanio 10 litre storage water heater...
# ...         ...                                                ...
# 1490   756K5DYZ  Prestige iris 750 watt mixer grinder with 3 st...
# 1491   1LY9W8AF  Cello eliza plastic laundry bag/basket, 50 lit...
# 1492   91JF2TFD  Boult audio bassbuds oak in-ear wired earphone...
# 1493   B3JSWG81  Ngi store 2 pieces pet hair removers for your ...
# 1494   0PVT30YI  Kitchen mart stainless steel south indian filt...
#
#                                                category  \
# 0      Electronics|homeaudio|speakers|bluetoothspeakers
# ...

# %%
df['discount_percentage'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# rating : Missing values, convert data type to Float, rating should be between 1 and 5.

# %%
df['rating']
df['rating'].isna().sum()
# Out:
# np.int64(27)

# %%
df['rating']
# Out:
# 0       4.2
# 1       4.3
# 2       4.3
# 3       4.6
# 4       4.4
#        ...
# 1490    3.9
# 1491    4.2
# 1492    3.9
# 1493    3.1
# 1494    4.1
# Name: rating, Length: 1455, dtype: object

# %%
df['rating'] = pd.to_numeric(df['rating'],errors='coerce')
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1055126195.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = pd.to_numeric(df['rating'],errors='coerce')

# %%
df['rating'].dtype
# Out:
# dtype('float64')

# %%
df['rating']
# Out:
# 0       4.2
# 1       4.3
# 2       4.3
# 3       4.6
# 4       4.4
#        ...
# 1490    3.9
# 1491    4.2
# 1492    3.9
# 1493    3.1
# 1494    4.1
# Name: rating, Length: 1455, dtype: float64

# %%
df.loc[(df['rating'] < 1)| (df['rating'] > 5 ),"rating"]= np.nan

# %%
df[df['rating'] < 1]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, Discounted_Price (INR), actual_price, discount_percentage, rating, Rating Count, about_product, user_id, user_name, review_id, review_title, review_content, IMG_LINK , product_link]
# Index: []

# %%
df['rating'] = df['rating'].fillna(df['rating'].median())
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/3809259488.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].fillna(df['rating'].median())

# %%
df['rating'].isna().sum()
# Out:
# np.int64(0)

# %%
df['rating']
# Out:
# 0       4.2
# 1       4.3
# 2       4.3
# 3       4.6
# 4       4.4
#        ...
# 1490    3.9
# 1491    4.2
# 1492    3.9
# 1493    3.1
# 1494    4.1
# Name: rating, Length: 1455, dtype: float64

# %% [markdown]
# Rating Count : Remove commas, convert data type to Int, all values should be ≥ 0.

# %%
df['Rating Count'] = df['Rating Count'].str.replace(',' ,'')
df['Rating Count'] = df['Rating Count'].str.replace('k' ,'')
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1936346042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating Count'] = df['Rating Count'].str.replace(',' ,'')
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1936346042.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating Count'] = df['Rating Count'].str.replace('k' ,'')

# %%
df['Rating Count'] = pd.to_numeric(df['Rating Count'],errors='coerce')
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/3507775953.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating Count'] = pd.to_numeric(df['Rating Count'],errors='coerce')

# %%
df['Rating Count'].dtype
# Out:
# dtype('float64')

# %%
df['Rating Count']
# Out:
# 0        2908.0
# 1        2664.0
# 2        1811.0
# 3       12375.0
# 4        1771.0
#          ...
# 1490    43070.0
# 1491     7274.0
# 1492     1173.0
# 1493        2.0
# 1494     4238.0
# Name: Rating Count, Length: 1455, dtype: float64

# %%
df[df['Rating Count'] <= 0]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, Discounted_Price (INR), actual_price, discount_percentage, rating, Rating Count, about_product, user_id, user_name, review_id, review_title, review_content, IMG_LINK , product_link]
# Index: []

# %%
df['Rating Count'] = df['Rating Count'].fillna(df['Rating Count'].median())
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1116523847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating Count'] = df['Rating Count'].fillna(df['Rating Count'].median())

# %%
df['Rating Count'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# about_product : 30 missing values, remove extra spaces and unwanted special characters.

# %%
df['about_product']
df['about_product'] = df['about_product'].fillna('Unknown')
df['about_product'].isna().sum()
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1738414845.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['about_product'] = df['about_product'].fillna('Unknown')
# np.int64(0)

# %%
df['about_product'] = df['about_product'].str.capitalize()
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1220541739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['about_product'] = df['about_product'].str.capitalize()

# %%
df[df['about_product'] == df['about_product'].str.upper()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, Discounted_Price (INR), actual_price, discount_percentage, rating, Rating Count, about_product, user_id, user_name, review_id, review_title, review_content, IMG_LINK , product_link]
# Index: []

# %%
df['about_product']
# Out:
# 0       Power- get ready to be enthralled by the 5w rm...
# 1       Special anti-microbial(biocide treated) paper ...
# 2       3 boiling modes - the advanced appliance from ...
# 3       Quieter click: logitech’s silenttouch technolo...
# 4       Suitable for high-rise buildings and pressure ...
#                               ...
# 1490    Motor warranty: 2; product warranty: 2;|operat...
# 1491    Material: plastic, color: light grey100% food ...
# 1492    In-line controls: answer/reject/ calls, play/p...
# 1493    Versatile, protects your clothes: movecatcher ...
# 1494    Material: food grade stainless steel; make aut...
# Name: about_product, Length: 1455, dtype: object

# %%
df['about_product'] = df['about_product'].str.replace(r'[^\w\s]',' ',regex=True)
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/2621928525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['about_product'] = df['about_product'].str.replace(r'[^\w\s]',' ',regex=True)

# %%
df['about_product']
# Out:
# 0       Power  get ready to be enthralled by the 5w rm...
# 1       Special anti microbial biocide treated  paper ...
# 2       3 boiling modes   the advanced appliance from ...
# 3       Quieter click  logitech s silenttouch technolo...
# 4       Suitable for high rise buildings and pressure ...
#                               ...
# 1490    Motor warranty  2  product warranty  2  operat...
# 1491    Material  plastic  color  light grey100  food ...
# 1492    In line controls  answer reject  calls  play p...
# 1493    Versatile  protects your clothes  movecatcher ...
# 1494    Material  food grade stainless steel  make aut...
# Name: about_product, Length: 1455, dtype: object

# %%
df['about_product'] = df['about_product'].str.strip()
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/2681377319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['about_product'] = df['about_product'].str.strip()

# %% [markdown]
# user_id : 30 missing values, ensure proper formatting and remove extra spaces.

# %%
df['user_id'].unique()
# Out:
# array(['AHL435VQHZZXB545DXGLIZSACFOQ,AG6OEN75DD6ADCNOYEGCMHZRI22A,AF3CWTDKJKG76CDV3IL6X72ZC6EA,AF73CGOZKN7MGOT7NZBIJFV35UQA,AF4CMSAMBV4RKGO4LWDE4LY5K2QQ,AGVG3B4ICKXGMOKDYKEOWIAO7LSA,AFVLASKUEKD7ILQRPFL4TAUJAUUA,AH2Z5DXERV53SFHROV27HKERTZPA',
#        'AEAHCVLMYLKLICSIKCTUS54NVQ2A,AFRIWQJKFSDZKTRTU5RSBKSQMIVA,AHFQXP2EQZOT7NTNHK5TMB6QA5QQ,AGLL6YL7RHHSDDGKWQO7ZIG3TXDQ,AGT4T2NBHXL5XVSRRCKSIGW7LDJA,AEAZZCC5KRGSGXGTGBRNK2O6IDAQ,AGBESE5F5QORNV2B6HE4UL4AMZ7Q,AE7QJ5FKTIU6K26GFQWGMXKO2MGQ',
#        ' AH2NLR3ZG7SADP6RTRU5PDZUBKYQ,AEDHYDNNCKCAOWK442JABEE5CWLQ,AEAT6CQT34IWYKUHXFMFGRNU7Q2A,AGZ3OTE7V74KVKLKR3PS2YSCM5QQ,AHURSRZTOF3NCYIB5RPFTXSHAEQQ,AFJ4QE5S3Y4YQR2FV36TS7QDG2KQ,AFWGKSA7JKANXBJVXLCPW7NR6ICQ,AHZYN7O73FJWRPUQGZM5BEAZ3A4A  ',
#        ...,
#        'AHYZC7TAK75CSXYF2V57TT2XB3VA,AHVSVASRHLY4HII4CH5GEKNUWAIQ,AHU3G6JL2C765DSFVXYNANCGFATA,AEF7R2XPRQEBGHMMUTQRQNQ7CHLQ,AHMWV64SEF7KPL6YJUVNNIAIEHJA,AHBVHPQ4W6276E6FKYIQHJQ4BMRQ,AH6ZGBUYPQH5WWPNBBMYQMYOOYTA,AH4XKLZAXDJGMB74RNSTAQD6T33Q',
# ...

# %%
df['user_id'].isna().sum()
# Out:
# np.int64(10)

# %%
df['user_id'] = df['user_id'].fillna('Unknown')
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/461750104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['user_id'] = df['user_id'].fillna('Unknown')

# %%
df.loc[(df['user_id'] != df['user_id'].str.upper()) & (df['user_id'] != 'Unknown')]
# Out:
#      product_id product_name category  Discounted_Price (INR)  actual_price  \
# 33            0            0        0                     0.0           0.0
# 57            0            0        0                     0.0           0.0
# 62            0            0        0                     0.0           0.0
# 71            0            0        0                     0.0           0.0
# 94            0            0        0                     0.0           0.0
# 98            0            0        0                     0.0           0.0
# 101           0            0        0                     0.0           0.0
# 229           0            0        0                     0.0           0.0
# 237           0            0        0                     0.0           0.0
# 258           0            0        0                     0.0           0.0
# 274           0            0        0                     0.0           0.0
# ...

# %%
df[df['user_id'] == 'Unknown']
# Out:
#      product_id product_name category  Discounted_Price (INR)  actual_price  \
# 13          NaN          NaN      NaN                   799.0        1650.0
# 100         NaN          NaN      NaN                     NaN        1650.0
# 329     Unknown          NaN      NaN                   799.0        1650.0
# 476         NaN          NaN      NaN                     NaN           NaN
# 647         NaN          NaN      NaN                     NaN           NaN
# 766         NaN          NaN      NaN                     NaN           NaN
# 779         NaN          NaN      NaN                     NaN           NaN
# 807         NaN          NaN      NaN                     NaN           NaN
# 996         NaN          NaN      NaN                     NaN           NaN
# 1227        NaN          NaN      NaN                     NaN           NaN
#
#       discount_percentage  rating  Rating Count about_product  user_id  \
# ...

# %%
df['user_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['user_id'] = df['user_id'].replace([0, '0'], 'Unknown')
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1378890299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['user_id'] = df['user_id'].replace([0, '0'], 'Unknown')

# %%
df[df['user_id'] == 'Unknown']
# Out:
#      product_id product_name category  Discounted_Price (INR)  actual_price  \
# 13          NaN          NaN      NaN                   799.0        1650.0
# 33            0            0        0                     0.0           0.0
# 57            0            0        0                     0.0           0.0
# 62            0            0        0                     0.0           0.0
# 71            0            0        0                     0.0           0.0
# 94            0            0        0                     0.0           0.0
# 98            0            0        0                     0.0           0.0
# 100         NaN          NaN      NaN                     NaN        1650.0
# 101           0            0        0                     0.0           0.0
# 229           0            0        0                     0.0           0.0
# 237           0            0        0                     0.0           0.0
# ...

# %%
df['user_id'] = df['user_id'].str.strip()
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/2023772855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['user_id'] = df['user_id'].str.strip()

# %% [markdown]
# user_name : 30 missing values, convert into Proper Case and remove extra spaces.

# %%
df['user_name']
# Out:
# 0       Devashish Gautam,Vishakha,Sunny Tanna,Dr.Suman...
# 1       Lulzdrone,KRISH,Harsh Shah,Harsh,HaPa,Inderjee...
# 2       Tapan Dutta,Seerat Dar,Saravana Kumar K N,Prad...
# 3       Awesome Shopper,Suresh madaka,Amazon Customer,...
# 4       Amazon Customer,Gaurav,khalil shaikh,Aman Seti...
#                               ...
# 1490    Prabhat,Chandrika,Pramesh969,Prity,Amit Kumar,...
# 1491    Amit Singh,RN,Madhuri,SHUKDEB P.,Mano,Harsha,m...
# 1492    Kulasekaranslrk,Amazon Customer,Sampada,Rudrak...
# 1493                                            Kunal Sen
# 1494    Amazon Customer,meena polkam,Amazon Customer,N...
# Name: user_name, Length: 1455, dtype: object

# %%
df['user_name'].isna().sum()
df['user_name'] = df['user_name'].fillna('Unknown')
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/990351884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['user_name'] = df['user_name'].fillna('Unknown')

# %%
df['user_name'].isna().sum()
# Out:
# np.int64(0)

# %%
df[df['user_name'] == df['user_name'].str.lower()]
df['user_name'] = df['user_name'].str.title()
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1525934292.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['user_name'] = df['user_name'].str.title()

# %%
df[df['user_name'] == df['user_name'].str.lower()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, Discounted_Price (INR), actual_price, discount_percentage, rating, Rating Count, about_product, user_id, user_name, review_id, review_title, review_content, IMG_LINK , product_link]
# Index: []

# %%
df.loc[df['user_name'].str.contains(r'[^A-Za-z0-9,.\s]',na= False),'user_name']
df['user_name']= df['user_name'].str.replace(r'[^A-Za-z0-9,.\s]', "",regex= True)
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/618519441.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['user_name']= df['user_name'].str.replace(r'[^A-Za-z0-9,.\s]', "",regex= True)

# %%
df[df['user_name'].isna()]
df['user_name']  = df['user_name'].fillna('Unknown')
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/240582187.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['user_name']  = df['user_name'].fillna('Unknown')

# %%
df[df['user_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, Discounted_Price (INR), actual_price, discount_percentage, rating, Rating Count, about_product, user_id, user_name, review_id, review_title, review_content, IMG_LINK , product_link]
# Index: []

# %% [markdown]
# review_id : Check duplicate values and ensure all Review IDs are unique.

# %%
df['review_id'].nunique()
# Out:
# 1131

# %%
df['review_id'].isna().sum()
# Out:
# np.int64(10)

# %%
df['review_id'].duplicated().sum()
# Out:
# np.int64(323)

# %%
df.loc[df['review_id'].duplicated(keep=False),['review_id']].value_counts()
# Out:
# review_id
# 0                                                                                                                          48
# R3F4T5TRYPTMIG,R3DQIEC603E7AY,R1O4Z15FD40PV5,RDVX50PD4CTFE,R3H6WKG0TA5CGU,R3Q3L1KP5QWPV3,RU0LU2PAIIME,R20FTANBPFA653       10
# R2K5OD0MEEBTDL,RS1N6TNO33BOK,R6KWBGOKI1N9Y,R30SKUMYLSXXDN,R1EOYHZWCRSV7B,R13JBDK4SAAYFT,RJOU5K9ECNW7Y,R2APPRANV6IERZ        8
# RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RYGGS0M09S3KY,R17KQRUTAN5DKS,R3AAQGS6HP2QUK,R1HDNOG6TO2CCA,R3PHKXYA5AFEOU       7
# R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1CLH2ULIVG5U3,R2DMKIBGFKBD6R,RC89B5IAJUTR5,R3B3DDON5FH8DS,R13WAEJDI5RS36       7
#                                                                                                                            ..
# R2PNR69G0BQG2F,R31A0WWDEYMKEW,R2C4XEWFLVU7JV,RYWES5AT5FQO6,R1PGWAY5TEWLT4,R32542OPR0QC4I,R2JDJEVZ2G7EEK,R36EHHPAQNSSOF      2
# ...

# %%
df['review_id'] = df['review_id'].replace(0 , np.nan)
# Out:
# /var/folders/qw/_nk9z1hd74q9vjp80k85r5l80000gn/T/ipykernel_33456/1155926740.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review_id'] = df['review_id'].replace(0 , np.nan)

# %%
df.loc[df['review_id'].duplicated(keep=False)]
# Out:
#      product_id                                       product_name  \
# 6      B4F1YC3J  Samsung galaxy m13 5g (aqua green, 6gb, 128gb ...
# 8      BBN3WF7V  Redmi a1 (light green, 2gb ram 32gb rom) | seg...
# 13          NaN                                                NaN
# 14     B86CDHL1  Oraimo 65w type c to c fast charging cable usb...
# 16     0P93X2H6  Classmate pulse spiral notebook - 240 mm x 180...
# ...         ...                                                ...
# 1475   bdrvfdkp  Sandisk ultra® microsdxc™ uhs-i card, 64gb, 14...
# 1478   B1YY6JJL  Acer 109 cm (43 inches) i series 4k ultra hd a...
# 1482   92BJMT8Q  Samsung 108 cm (43 inches) crystal 4k series u...
# 1483   8Y5QJXSR  Atomberg renesa 1200mm bldc motor with remote ...
# 1486          0                                                  0
#
#                                                category  \
# 6     Electronics|mobiles&accessories|smartphones&ba...
# ...

# %%
df.loc[
    df['review_id'].isin(
        df['review_id'].value_counts().loc[lambda x: x > 1].index
    )
].sort_values('review_id')
# Out:
#      product_id                                       product_name  \
# 696    7GVGTSLN  Wayona usb type c fast charger cable fast char...
# 774    7GVGTSLN  Wayona usb type c fast charger cable fast char...
# 196    7F1P8KNV  Wayona nylon braided usb type c 3ft 1m 3a fast...
# 70     B5LVS732  Noise pulse go buzz smart watch bluetooth call...
# 613    B5LVS732  Noise pulse go buzz smart watch bluetooth call...
# ...         ...                                                ...
# 77     B53QLB9H  Ptron newly launched force x10 bluetooth calli...
# 1276   B53QFZPY  Ptron newly launched force x10 bluetooth calli...
# 808    B4G2MWSB  Lapster 5 pin mini usb cable, usb b cable,came...
# 419    994GFWBH  Lapster 1.5 mtr usb 2.0 type a male to usb a m...
# 798    994GFWBH  Lapster 1.5 mtr usb 2.0 type a male to usb a m...
#
#                                                category  \
# 696   Computers&accessories|accessories&peripherals|...
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(54)

# %%
df = df.drop_duplicates()

# %%
df.loc[
    df['review_id'].isin(
        df['review_id'].value_counts().loc[lambda x: x > 1].index
    )
].sort_values('review_id')
# Out:
#      product_id                                       product_name  \
# 774    7GVGTSLN  Wayona usb type c fast charger cable fast char...
# 196    7F1P8KNV  Wayona nylon braided usb type c 3ft 1m 3a fast...
# 696    7GVGTSLN  Wayona usb type c fast charger cable fast char...
# 613    B5LVS732  Noise pulse go buzz smart watch bluetooth call...
# 70     B5LVS732  Noise pulse go buzz smart watch bluetooth call...
# ...         ...                                                ...
# 77     B53QLB9H  Ptron newly launched force x10 bluetooth calli...
# 1276   B53QFZPY  Ptron newly launched force x10 bluetooth calli...
# 798    994GFWBH  Lapster 1.5 mtr usb 2.0 type a male to usb a m...
# 419    994GFWBH  Lapster 1.5 mtr usb 2.0 type a male to usb a m...
# 808    B4G2MWSB  Lapster 5 pin mini usb cable, usb b cable,came...
#
#                                                category  \
# 774   Computers&accessories|accessories&peripherals|...
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['review_id'].value_counts().loc[lambda x: x > 1]
# Out:
# review_id
# R3F4T5TRYPTMIG,R3DQIEC603E7AY,R1O4Z15FD40PV5,RDVX50PD4CTFE,R3H6WKG0TA5CGU,R3Q3L1KP5QWPV3,RU0LU2PAIIME,R20FTANBPFA653     10
# R2K5OD0MEEBTDL,RS1N6TNO33BOK,R6KWBGOKI1N9Y,R30SKUMYLSXXDN,R1EOYHZWCRSV7B,R13JBDK4SAAYFT,RJOU5K9ECNW7Y,R2APPRANV6IERZ      8
# RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RYGGS0M09S3KY,R17KQRUTAN5DKS,R3AAQGS6HP2QUK,R1HDNOG6TO2CCA,R3PHKXYA5AFEOU     7
# R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1KD19VHEDV0OR,R3C02RMYQMK6FC,R39GQRVBUZBWGY,R2K9EDOE15QIRJ,R3OI7YT648TL8I     7
# R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1CLH2ULIVG5U3,R2DMKIBGFKBD6R,RC89B5IAJUTR5,R3B3DDON5FH8DS,R13WAEJDI5RS36     7
#                                                                                                                          ..
# R2ACU430AWSQ15,RZFPMZJQG4VEF,R2P7VTDLLMDOA3,R1B9M17A3N27E2,R4LNZP9RCX3H3,R3TL5BYHCMQSB3,R1B2BRD05LJZX4,R2WQKUAV6WUQ06     2
# ...

# %%
df.drop(
df[df['review_id'] == 'R2K5OD0MEEBTDL,RS1N6TNO33BOK,R6KWBGOKI1N9Y,R30SKUMYLSXXDN,R1EOYHZWCRSV7B,R13JBDK4SAAYFT,RJOU5K9ECNW7Y,R2APPRANV6IERZ'].index,inplace= True
)

# %%
df['review_id'].duplicated().sum()
# Out:
# np.int64(263)

# %%
df[df['review_id'] == 'R2K5OD0MEEBTDL,RS1N6TNO33BOK,R6KWBGOKI1N9Y,R30SKUMYLSXXDN,R1EOYHZWCRSV7B,R13JBDK4SAAYFT,RJOU5K9ECNW7Y,R2APPRANV6IERZ']
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, Discounted_Price (INR), actual_price, discount_percentage, rating, Rating Count, about_product, user_id, user_name, review_id, review_title, review_content, IMG_LINK , product_link]
# Index: []

# %%
df = df.drop_duplicates(subset='review_id',keep='first')

# %%
df['review_id'].value_counts().loc[lambda x: x > 1]
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.shape
# Out:
# (1130, 16)

# %%
data.shape
# Out:
# (1495, 16)

# %%
df['review_id'].isna().sum()
# Out:
# np.int64(1)

# %% [markdown]
# review_title : 30 missing values, remove extra spaces and unwanted symbols.

# %%
df['review_title'].isna().sum()
# Out:
# np.int64(4)

# %%
df[df['review_title'].str.contains(r'[^A-Za-z0-9,.\s]' , na=False) ]
df['review_title']=df['review_title'].str.replace(r'[^A-Za-z0-9,\s]','',regex=True)
df['review_title']
# Out:
# 0       Strudy, Awesome connectivitybut bass is NOT up...
# 1       Bigger size,Superb,Vacuum Bag,Price is reasona...
# 2       Nice good,Easy to use,Good , however little co...
# 3       Good but the scroll is now damaged,Nice,Noisel...
# 4       Good product but attention needed in packing a...
#                               ...
# 1490    Juicer is not effective,Ok good,Products quali...
# 1491    Nice product,Ok,The lid could be more sturdier...
# 1492    Does its job for the price,Not for music but c...
# 1493                                              Useless
# 1494    Coffee Filter,Just go for it,Happy with the pr...
# Name: review_title, Length: 1130, dtype: object

# %%
df['review_title'].isna().sum()
# Out:
# np.int64(4)

# %%
df['review_title'] = df['review_title'].fillna('Unknown')

# %%
df['review_title'].isna().sum()
# Out:
# np.int64(0)

# %%
df['review_title'] = df['review_title'].str.strip()

# %% [markdown]
# review_content : 30 missing values, clean unwanted spaces, special characters and blank text.

# %%
df['review_content']
# Out:
# 0       The LED light is vibrant with multiple form se...
# 1       These are the biggest one their models use and...
# 2       Like it,Awesome product 😊,Follow the instructi...
# 3       - excellent piece of wireless mouse- reasonabl...
# 4       For this price range product design, look, spe...
#                               ...
# 1490    Juicer is not effective,Ok good,https://m.medi...
# 1491    It's a good product for strong daily laundry c...
# 1492    A peculiar product in the market. Good sound q...
# 1493    Does not work as advertised at all. The pieces...
# 1494    Coffee Filter is just the right size for a sma...
# Name: review_content, Length: 1130, dtype: object

# %%
df.loc[df['review_content'].str.contains(r'[^A-Za-z0-9,.\s]', na=False) , ['review_content']]
df['review_content']= df['review_content'].str.replace(r'[^A-Za-z0-9,.\s]',"" ,regex=True)
df['review_content']
# Out:
# 0       The LED light is vibrant with multiple form se...
# 1       These are the biggest one their models use and...
# 2       Like it,Awesome product ,Follow the instructio...
# 3       excellent piece of wireless mouse reasonable p...
# 4       For this price range product design, look, spe...
#                               ...
# 1490    Juicer is not effective,Ok good,httpsm.mediaam...
# 1491    Its a good product for strong daily laundry cl...
# 1492    A peculiar product in the market. Good sound q...
# 1493    Does not work as advertised at all. The pieces...
# 1494    Coffee Filter is just the right size for a sma...
# Name: review_content, Length: 1130, dtype: object

# %%
df['review_content'].isna().sum()
# Out:
# np.int64(2)

# %%
df['review_content'] = df['review_content'].fillna('Unknown')

# %%
df['review_content'] = df['review_content'].str.strip()

# %% [markdown]
# IMG_LINK : 30 missing values, ensure all links are valid and start with https://.

# %%
df['IMG_LINK ']
# Out:
# 0       https://m.media-amazon.com/images/I/51J45Dcgkt...
# 1       https://m.media-amazon.com/images/W/WEBP_40237...
# 2       https://m.media-amazon.com/images/I/41yrqUum9E...
# 3       https://m.media-amazon.com/images/W/WEBP_40237...
# 4       https://m.media-amazon.com/images/I/31-XtyZy0I...
#                               ...
# 1490    https://m.media-amazon.com/images/W/WEBP_40237...
# 1491    https://m.media-amazon.com/images/I/51CyJ9dUiW...
# 1492    https://m.media-amazon.com/images/W/WEBP_40237...
# 1493    https://m.media-amazon.com/images/W/WEBP_40237...
# 1494                                                  NaN
# Name: IMG_LINK , Length: 1130, dtype: object

# %%
df['IMG_LINK '].isna().sum()
# Out:
# np.int64(8)

# %%
df.loc[~df['IMG_LINK '].str.contains('https:',na= False)]
# Out:
#      product_id                                       product_name  \
# 13          NaN                                                NaN
# 83     8LHTJTBB  Dyazo 6 angles adjustable aluminum ergonomic f...
# 224    7Y9PY6Y1  Sujata powermatic plus, juicer mixer grinder w...
# 302    BBFJ9M3X  Redmi 11 prime 5g (meadow green, 4gb ram 64gb ...
# 321    BMGB2TPR  Samsung galaxy m04 light green, 4gb ram, 64gb ...
# 367    7WDKLDRX  Iqoo neo 6 5g (dark nova, 8gb ram, 128gb stora...
# 378    9Z7YGV3R  Anjaney enterprise smart multipurpose foldable...
# 541    7GLSKXS1  Kent 16026 electric kettle stainless steel 1.8...
# 599    09P2LK08  Bajaj minor 1000 watts radiant room heater (st...
# 733    9Z28BQZT  Amazon basics multipurpose foldable laptop tab...
# 754    7RX14W1Q  Amazon basics 10.2 gbps high-speed 4k hdmi cab...
# 822    BBW521YC  Lapster 12pcs spiral cable protectors for char...
# 845    77T3BG5L  Zebronics zeb-km2100 multimedia usb keyboard c...
# ...

# %%
df['IMG_LINK '].shape
# Out:
# (1130,)

# %%
mask = df['IMG_LINK '].notna() & ~df['IMG_LINK '].str.startswith('https://',na=False)
df.loc[mask,'IMG_LINK '] = 'https://' + df.loc[mask , 'IMG_LINK ']

# %%
df.loc[~df['IMG_LINK '].str.contains('https:',na= False)]
# Out:
#      product_id                                       product_name  \
# 13          NaN                                                NaN
# 83     8LHTJTBB  Dyazo 6 angles adjustable aluminum ergonomic f...
# 754    7RX14W1Q  Amazon basics 10.2 gbps high-speed 4k hdmi cab...
# 950    83RC4WFJ  Prettykrafts laundry bag / basket for dirty cl...
# 1250   9J2SCVQT  Nutripro juicer mixer grinder - smoothie maker...
# 1396   0EDJJ7FS  Philips viva collection hd4928/01 2100-watt in...
# 1442   9V12K8NT  Boat wave lite smartwatch with 1.69" hd displa...
# 1494   0PVT30YI  Kitchen mart stainless steel south indian filt...
#
#                                                category  \
# 13                                                  NaN
# 83    Computers&accessories|accessories&peripherals|...
# 754   Electronics|hometheater,tv&video|accessories|c...
# 950   Home&kitchen|homestorage&organization|laundryo...
# 1250  Home&kitchen|kitchen&homeappliances|smallkitch...
# ...

# %%
df['IMG_LINK '] = df['IMG_LINK '].fillna('Unknown')

# %%
df['IMG_LINK '].isna().sum()
# Out:
# np.int64(0)

# %%
df['IMG_LINK '].dtype
# Out:
# dtype('O')

# %%
df['IMG_LINK '].str.contains('https:').sum()
# Out:
# np.int64(1122)

# %%
df['IMG_LINK '].shape
# Out:
# (1130,)

# %% [markdown]
# product_link : 30 missing values, ensure all links are valid and remove broken URLs.

# %%
df['product_link']
df['product_link'].str.contains('https:').sum()
# Out:
# 1097

# %%
df.loc[~df['product_link'].str.contains('https:',na=False)]
# Out:
#      product_id                                       product_name  \
# 11     7YNTJ8ZM  Zebronics zeb-county 3w wireless bluetooth por...
# 13          NaN                                                NaN
# 17     9TWHTBKQ  Samsung galaxy m33 5g (mystique green, 8gb, 12...
# 18     B84KSH3X  Wipro vesta 1200 watt gd203 heavyweight automa...
# 63     B9XN9S3W  Acer 80 cm (32 inches) n series hd ready tv ar...
# 74     96YCN3SD  Lifelong llek15 electric kettle 1.5l with stai...
# 150    8MV82R99   bajaj waterproof 1500 watts immersion rod heater
# 163    82T6GVLJ  Amazon basics new release nylon usb-a to light...
# 191    B5GJRTHB  Wecool moonwalk m1 enc true wireless in ear ea...
# 207    7QCWY5XV  Mobilife bluetooth extendable selfie stick wit...
# 239    14SZO90Y          Duracell ultra alkaline aa battery, 8 pcs
# 240    9RWQ7YR6  Mi 138.8 cm (55 inches) 5x series 4k ultra hd ...
# 361    9GFLXVH9  Redmi 9a sport (coral green, 2gb ram, 32gb sto...
# ...

# %%
count_product = df['product_link'].notna() & ~df['product_link'].str.startswith('https://',na= False)
df.loc[count_product,'product_link'] = 'https://' + df.loc[count_product,'product_link']

# %%
df.loc[~df['product_link'].str.contains('https:',na=False)]
# Out:
#      product_id                                       product_name  \
# 13          NaN                                                NaN
# 18     B84KSH3X  Wipro vesta 1200 watt gd203 heavyweight automa...
# 74     96YCN3SD  Lifelong llek15 electric kettle 1.5l with stai...
# 239    14SZO90Y          Duracell ultra alkaline aa battery, 8 pcs
# 466    9VGKFM7Y  Amazon basics 2 amp usb wall charger & micro u...
# 789    8SKZ2RMG  Demokrazy new nova lint cum fuzz remover for a...
# 993    04IO5BMQ  Logitech m235 wireless mouse, 1000 dpi optical...
# 1261   BB3CBFBM  Vu 138 cm (55 inches) premium series 4k ultra ...
#
#                                                category  \
# 13                                                  NaN
# 18    Home&kitchen|kitchen&homeappliances|vacuum,cle...
# 74    Home&kitchen|kitchen&homeappliances|smallkitch...
# 239   Electronics|generalpurposebatteries&batterycha...
# 466   Electronics|mobiles&accessories|mobileaccessor...
# ...

# %%
df[df['product_id'] == 'B5GJRTHB']
# Out:
#     product_id                                       product_name  \
# 191   B5GJRTHB  Wecool moonwalk m1 enc true wireless in ear ea...
#
#                                               category  \
# 191  Electronics|headphones,earbuds&accessories|hea...
#
#      Discounted_Price (INR)  actual_price  discount_percentage  rating  \
# 191                   889.0        1999.0                 56.0     4.2
#
#      Rating Count                                      about_product  \
# 191        2284.0  We have designed the enc earbuds to provide ex...
#
#                                                user_id  \
# 191  AGMD2UVAWOKO3W37KGZWAPI3ZB6A,AG7BC5ADBMW6EMTNH...
#
#                                              user_name  \
# 191  Siddhesh S.,Karthik,Vikram Kanth,Dhanesh,Rani,...
#
#                                              review_id  \
# 191  R1R1JK1E1KZYX8,R2XZC0TY29XVLD,R10HYVIHZWKK1K,R...
#
#                                           review_title  \
# ...

# %%
df['product_link'] = df['product_link'].fillna('Unknown')

# %%
df['product_link'].isna().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Data Type : Convert all price, rating, discount and rating count columns into appropriate numeric data types.

# %%
df.dtypes
# Out:
# product_id                 object
# product_name               object
# category                   object
# Discounted_Price (INR)    float64
# actual_price              float64
# discount_percentage       float64
# rating                    float64
# Rating Count              float64
# about_product              object
# user_id                    object
# user_name                  object
# review_id                  object
# review_title               object
# review_content             object
# IMG_LINK                   object
# product_link               object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'Discounted_Price (INR)',
#        'actual_price', 'discount_percentage', 'rating', 'Rating Count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'IMG_LINK ', 'product_link'],
#       dtype='object')

# %%
df.to_csv('cleaned_amazon_data.csv')
